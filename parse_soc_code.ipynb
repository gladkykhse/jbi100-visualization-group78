# %%
from bs4 import BeautifulSoup
import os

def parse_local_html(file_path):
    """
    Reads a local HTML file and parses it using BeautifulSoup.

    Parameters:
        file_path (str): Path to the local HTML file.

    Returns:
        BeautifulSoup object: Parsed HTML ready for analysis.
    """
    # Open the HTML file
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup

# Example usage
file_path = os.path.join("datasets", 'soc_codes.html')
soup = parse_local_html(file_path)
soup.prettify()
# Out:
# "<ul>\n <li>\n  11-1000\xa0 Top Executives\n  <ul>\n   <li>\n    11-1010\xa0 Chief Executives\n    <ul>\n     <li>\n      11-1011 Chief Executives\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-1020\xa0 General and Operations Managers\n    <ul>\n     <li>\n      11-1021 General and Operations Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-1030\xa0 Legislators\n    <ul>\n     <li>\n      11-1031 Legislators\n     </li>\n    </ul>\n   </li>\n  </ul>\n </li>\n <li>\n  11-2000\xa0 Advertising, Marketing, Promotions, Public Relations, and Sales\n    Managers\n  <ul>\n   <li>\n    11-2010\xa0 Advertising and Promotions Managers\n    <ul>\n     <li>\n      11-2011 Advertising and Promotions Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-2020\xa0 Marketing and Sales Managers\n    <ul>\n     <li>\n      11-2021 Marketing Managers\n     </li>\n     <li>\n      11-2022 Sales Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-2030\xa0 Public Relations and Fundraising Managers\n    <ul>\n     <li>\n      11-2032 Public Relations Managers\n     </li>\n     <li>\n      11-2033 Fundraising Managers\n     </li>\n    </ul>\n   </li>\n  </ul>\n </li>\n <li>\n  11-3000\xa0 Operations Specialties Managers\n  <ul>\n   <li>\n    11-3010\xa0 Administrative Services and Facilities Managers\n    <ul>\n     <li>\n      11-3012 Administrative Services Managers\n     </li>\n     <li>\n      11-3013 Facilities Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3020\xa0 Computer and Information Systems Managers\n    <ul>\n     <li>\n      11-3021 Computer and Information Systems Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3030\xa0 Financial Managers\n    <ul>\n     <li>\n      11-3031 Financial Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3050\xa0 Industrial Production Managers\n    <ul>\n     <li>\n      11-3051 Industrial Production Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3060\xa0 Purchasing Managers\n    <ul>\n     <li>\n      11-3061 Purchasing Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3070\xa0 Transportation, Storage, and Distribution Managers\n    <ul>\n     <li>\n      11-3071 Transportation, Storage, and Distribution Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3110\xa0 Compensation and Benefits Managers\n    <ul>\n     <li>\n      11-3111 Compensation and Benefits Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3120\xa0 Human Resources Managers\n    <ul>\n     <li>\n      11-3121 Human Resources Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-3130\xa0 Training and Development Managers\n    <ul>\n     <li>\n      11-3131 Training and Development Managers\n     </li>\n    </ul>\n   </li>\n  </ul>\n </li>\n <li>\n  11-9000\xa0 Other Management Occupations\n  <ul>\n   <li>\n    11-9010\xa0 Farmers, Ranchers, and Other Agricultural Managers\n    <ul>\n     <li>\n      11-9013 Farmers, Ranchers, and Other Agricultural Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-9020\xa0 Construction Managers\n    <ul>\n     <li>\n      11-9021 Construction Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-9030\xa0 Education and Childcare Administrators\n    <ul>\n     <li>\n      11-9031 Education and Childcare Administrators, Preschool and Daycare\n     </li>\n     <li>\n      11-9032 Education Administrators, Kindergarten through Secondary\n     </li>\n     <li>\n      11-9033 Education Administrators, Postsecondary\n     </li>\n     <li>\n      11-9039 Education Administrators, All Other\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-9040\xa0 Architectural and Engineering Managers\n    <ul>\n     <li>\n      11-9041 Architectural and Engineering Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-9050\xa0 Food Service Managers\n    <ul>\n     <li>\n      11-9051 Food Service Managers\n     </li>\n    </ul>\n   </li>\n   <li>\n    11-9070\xa0 Entertainment and Recreation Managers\n    <ul>\n    ...

# %%
classifications = {
    "11-0000": "Management Occupations",
    "13-0000": "Business and Financial Operations Occupations",
    "15-0000": "Computer and Mathematical Occupations",
    "17-0000": "Architecture and Engineering Occupations",
    "19-0000": "Life, Physical, and Social Science Occupations",
    "21-0000": "Community and Social Service Occupations",
    "23-0000": "Legal Occupations",
    "25-0000": "Educational Instruction and Library Occupations",
    "27-0000": "Arts, Design, Entertainment, Sports, and Media Occupations",
    "29-0000": "Healthcare Practitioners and Technical Occupations",
    "31-0000": "Healthcare Support Occupations",
    "33-0000": "Protective Service Occupations",
    "35-0000": "Food Preparation and Serving Related Occupations",
    "37-0000": "Building and Grounds Cleaning and Maintenance Occupations",
    "39-0000": "Personal Care and Service Occupations",
    "41-0000": "Sales and Related Occupations",
    "43-0000": "Office and Administrative Support Occupations",
    "45-0000": "Farming, Fishing, and Forestry Occupations",
    "47-0000": "Construction and Extraction Occupations",
    "49-0000": "Installation, Maintenance, and Repair Occupations",
    "51-0000": "Production Occupations",
    "53-0000": "Transportation and Material Moving Occupations",
    "55-0000": "Military Specific Occupations"
}
cat1_list = list(classifications.values())

# %%
output = {}

for index, ul1 in enumerate(soup.find_all('ul', recursive=False)):
    cat1 = cat1_list[index]
    for li1 in ul1.find_all('li', recursive=False):
        text2 = li1.find(text=True, recursive=False).strip()
        cat2 = " ".join(text2.split()[1:]).strip()
        code = text2.split()[0].strip()
        output[code] = [cat1, cat2, "Not assigned"]
        for li2 in li1.find("ul").find_all("li", recursive=False):
            text3 = li2.find(text=True, recursive=False).strip()
            cat3 = " ".join(text3.split()[1:]).strip()
            code = text3.split()[0].strip()
            output[code] = [cat1, cat2, cat3]
            codes = [x.find(text=True, recursive=False).split()[0].strip() for x in li2.find("ul").find_all('li', recursive=False)]
            for code in codes:
                output[code] = [cat1, cat2, cat3]

output
# Out:
# C:\Users\Chekm\AppData\Local\Temp\ipykernel_12104\590815016.py:6: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text2 = li1.find(text=True, recursive=False).strip()
# C:\Users\Chekm\AppData\Local\Temp\ipykernel_12104\590815016.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text3 = li2.find(text=True, recursive=False).strip()
# C:\Users\Chekm\AppData\Local\Temp\ipykernel_12104\590815016.py:15: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   codes = [x.find(text=True, recursive=False).split()[0].strip() for x in li2.find("ul").find_all('li', recursive=False)]
# {'11-1000': ['Management Occupations', 'Top Executives', 'Not assigned'],
#  '11-1010': ['Management Occupations', 'Top Executives', 'Chief Executives'],
#  '11-1011': ['Management Occupations', 'Top Executives', 'Chief Executives'],
#  '11-1020': ['Management Occupations',
#   'Top Executives',
#   'General and Operations Managers'],
#  '11-1021': ['Management Occupations',
#   'Top Executives',
#   'General and Operations Managers'],
#  '11-1030': ['Management Occupations', 'Top Executives', 'Legislators'],
#  '11-1031': ['Management Occupations', 'Top Executives', 'Legislators'],
#  '11-2000': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Not assigned'],
#  '11-2010': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Advertising and Promotions Managers'],
#  '11-2011': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Advertising and Promotions Managers'],
#  '11-2020': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Marketing and Sales Managers'],
#  '11-2021': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Marketing and Sales Managers'],
#  '11-2022': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Marketing and Sales Managers'],
#  '11-2030': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Public Relations and Fundraising Managers'],
#  '11-2032': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Public Relations and Fundraising Managers'],
#  '11-2033': ['Management Occupations',
#   'Advertising, Marketing, Promotions, Public Relations, and Sales Managers',
#   'Public Relations and Fundraising Managers'],
#  '11-3000': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Not assigned'],
#  '11-3010': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Administrative Services and Facilities Managers'],
#  '11-3012': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Administrative Services and Facilities Managers'],
#  '11-3013': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Administrative Services and Facilities Managers'],
#  '11-3020': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Computer and Information Systems Managers'],
#  '11-3021': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Computer and Information Systems Managers'],
#  '11-3030': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Financial Managers'],
#  '11-3031': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Financial Managers'],
#  '11-3050': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Industrial Production Managers'],
#  '11-3051': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Industrial Production Managers'],
#  '11-3060': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Purchasing Managers'],
#  '11-3061': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Purchasing Managers'],
#  '11-3070': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Transportation, Storage, and Distribution Managers'],
#  '11-3071': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Transportation, Storage, and Distribution Managers'],
#  '11-3110': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Compensation and Benefits Managers'],
#  '11-3111': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Compensation and Benefits Managers'],
#  '11-3120': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Human Resources Managers'],
#  '11-3121': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Human Resources Managers'],
#  '11-3130': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Training and Development Managers'],
#  '11-3131': ['Management Occupations',
#   'Operations Specialties Managers',
#   'Training and Development Managers'],
#  '11-9000': ['Management Occupations',
#   'Other Management Occupations',
#   'Not assigned'],
#  '11-9010': ['Management Occupations',
#   'Other Management Occupations',
#   'Farmers, Ranchers, and Other Agricultural Managers'],
#  '11-9013': ['Management Occupations',
#   'Other Management Occupations',
#   'Farmers, Ranchers, and Other Agricultural Managers'],
#  '11-9020': ['Management Occupations',
#   'Other Management Occupations',
#   'Construction Managers'],
#  '11-9021': ['Management Occupations',
#   'Other Management Occupations',
#   'Construction Managers'],
#  '11-9030': ['Management Occupations',
#   'Other Management Occupations',
#   'Education and Childcare Administrators'],
#  '11-9031': ['Management Occupations',
#   'Other Management Occupations',
#   'Education and Childcare Administrators'],
#  '11-9032': ['Management Occupations',
#   'Other Management Occupations',
#   'Education and Childcare Administrators'],
#  '11-9033': ['Management Occupations',
#   'Other Management Occupations',
#   'Education and Childcare Administrators'],
#  '11-9039': ['Management Occupations',
#   'Other Management Occupations',
#   'Education and Childcare Administrators'],
#  '11-9040': ['Management Occupations',
#   'Other Management Occupations',
#   'Architectural and Engineering Managers'],
#  '11-9041': ['Management Occupations',
#   'Other Management Occupations',
#   'Architectural and Engineering Managers'],
#  '11-9050': ['Management Occupations',
#   'Other Management Occupations',
#   'Food Service Managers'],
#  '11-9051': ['Management Occupations',
#   'Other Management Occupations',
#   'Food Service Managers'],
#  '11-9070': ['Management Occupations',
#   'Other Management Occupations',
#   'Entertainment and Recreation Managers'],
#  '11-9071': ['Management Occupations',
#   'Other Management Occupations',
#   'Entertainment and Recreation Managers'],
#  '11-9072': ['Management Occupations',
#   'Other Management Occupations',
#   'Entertainment and Recreation Managers'],
#  '11-9080': ['Management Occupations',
#   'Other Management Occupations',
#   'Lodging Managers'],
#  '11-9081': ['Management Occupations',
#   'Other Management Occupations',
#   'Lodging Managers'],
#  '11-9110': ['Management Occupations',
#   'Other Management Occupations',
#   'Medical and Health Services Managers'],
#  '11-9111': ['Management Occupations',
#   'Other Management Occupations',
#   'Medical and Health Services Managers'],
#  '11-9120': ['Management Occupations',
#   'Other Management Occupations',
#   'Natural Sciences Managers'],
#  '11-9121': ['Management Occupations',
#   'Other Management Occupations',
#   'Natural Sciences Managers'],
#  '11-9130': ['Management Occupations',
#   'Other Management Occupations',
#   'Postmasters and Mail Superintendents'],
#  '11-9131': ['Management Occupations',
#   'Other Management Occupations',
#   'Postmasters and Mail Superintendents'],
#  '11-9140': ['Management Occupations',
#   'Other Management Occupations',
#   'Property, Real Estate, and Community Association Managers'],
#  '11-9141': ['Management Occupations',
#   'Other Management Occupations',
#   'Property, Real Estate, and Community Association Managers'],
#  '11-9150': ['Management Occupations',
#   'Other Management Occupations',
#   'Social and Community Service Managers'],
#  '11-9151': ['Management Occupations',
#   'Other Management Occupations',
#   'Social and Community Service Managers'],
#  '11-9160': ['Management Occupations',
#   'Other Management Occupations',
#   'Emergency Management Directors'],
#  '11-9161': ['Management Occupations',
#   'Other Management Occupations',
#   'Emergency Management Directors'],
#  '11-9170': ['Management Occupations',
#   'Other Management Occupations',
#   'Personal Service Managers'],
#  '11-9171': ['Management Occupations',
#   'Other Management Occupations',
#   'Personal Service Managers'],
#  '11-9179': ['Management Occupations',
#   'Other Management Occupations',
#   'Personal Service Managers'],
#  '11-9190': ['Management Occupations',
#   'Other Management Occupations',
#   'Miscellaneous Managers'],
#  '11-9199': ['Management Occupations',
#   'Other Management Occupations',
#   'Miscellaneous Managers'],
#  '13-1000': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Not assigned'],
#  '13-1010': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Agents and Business Managers of Artists, Performers, and Athletes'],
#  '13-1011': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Agents and Business Managers of Artists, Performers, and Athletes'],
#  '13-1020': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Buyers and Purchasing Agents'],
#  '13-1021': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Buyers and Purchasing Agents'],
#  '13-1022': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Buyers and Purchasing Agents'],
#  '13-1023': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Buyers and Purchasing Agents'],
#  '13-1030': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Claims Adjusters, Appraisers, Examiners, and Investigators'],
#  '13-1031': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Claims Adjusters, Appraisers, Examiners, and Investigators'],
#  '13-1032': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Claims Adjusters, Appraisers, Examiners, and Investigators'],
#  '13-1040': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Compliance Officers'],
#  '13-1041': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Compliance Officers'],
#  '13-1050': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Cost Estimators'],
#  '13-1051': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Cost Estimators'],
#  '13-1070': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Human Resources Workers'],
#  '13-1071': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Human Resources Workers'],
#  '13-1074': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Human Resources Workers'],
#  '13-1075': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Human Resources Workers'],
#  '13-1080': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Logisticians and Project Management Specialists'],
#  '13-1081': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Logisticians and Project Management Specialists'],
#  '13-1082': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Logisticians and Project Management Specialists'],
#  '13-1110': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Management Analysts'],
#  '13-1111': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Management Analysts'],
#  '13-1120': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Meeting, Convention, and Event Planners'],
#  '13-1121': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Meeting, Convention, and Event Planners'],
#  '13-1130': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Fundraisers'],
#  '13-1131': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Fundraisers'],
#  '13-1140': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Compensation, Benefits, and Job Analysis Specialists'],
#  '13-1141': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Compensation, Benefits, and Job Analysis Specialists'],
#  '13-1150': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Training and Development Specialists'],
#  '13-1151': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Training and Development Specialists'],
#  '13-1160': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Market Research Analysts and Marketing Specialists'],
#  '13-1161': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Market Research Analysts and Marketing Specialists'],
#  '13-1190': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Miscellaneous Business Operations Specialists'],
#  '13-1199': ['Business and Financial Operations Occupations',
#   'Business Operations Specialists',
#   'Miscellaneous Business Operations Specialists'],
#  '13-2000': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Not assigned'],
#  '13-2010': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Accountants and Auditors'],
#  '13-2011': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Accountants and Auditors'],
#  '13-2020': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Property Appraisers and Assessors'],
#  '13-2022': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Property Appraisers and Assessors'],
#  '13-2023': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Property Appraisers and Assessors'],
#  '13-2030': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Budget Analysts'],
#  '13-2031': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Budget Analysts'],
#  '13-2040': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Credit Analysts'],
#  '13-2041': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Credit Analysts'],
#  '13-2050': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Analysts and Advisors'],
#  '13-2051': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Analysts and Advisors'],
#  '13-2052': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Analysts and Advisors'],
#  '13-2053': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Analysts and Advisors'],
#  '13-2054': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Analysts and Advisors'],
#  '13-2060': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Examiners'],
#  '13-2061': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Financial Examiners'],
#  '13-2070': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Credit Counselors and Loan Officers'],
#  '13-2071': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Credit Counselors and Loan Officers'],
#  '13-2072': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Credit Counselors and Loan Officers'],
#  '13-2080': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Tax Examiners, Collectors and Preparers, and Revenue Agents'],
#  '13-2081': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Tax Examiners, Collectors and Preparers, and Revenue Agents'],
#  '13-2082': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Tax Examiners, Collectors and Preparers, and Revenue Agents'],
#  '13-2090': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Miscellaneous Financial Specialists'],
#  '13-2099': ['Business and Financial Operations Occupations',
#   'Financial Specialists',
#   'Miscellaneous Financial Specialists'],
#  '15-1200': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Not assigned'],
#  '15-1210': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer and Information Analysts'],
#  '15-1211': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer and Information Analysts'],
#  '15-1212': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer and Information Analysts'],
#  '15-1220': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer and Information Research Scientists'],
#  '15-1221': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer and Information Research Scientists'],
#  '15-1230': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer Support Specialists'],
#  '15-1231': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer Support Specialists'],
#  '15-1232': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Computer Support Specialists'],
#  '15-1240': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Database and Network Administrators and Architects'],
#  '15-1241': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Database and Network Administrators and Architects'],
#  '15-1242': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Database and Network Administrators and Architects'],
#  '15-1243': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Database and Network Administrators and Architects'],
#  '15-1244': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Database and Network Administrators and Architects'],
#  '15-1250': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1251': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1252': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1253': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1254': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1255': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Software and Web Developers, Programmers, and Testers'],
#  '15-1290': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Miscellaneous Computer Occupations'],
#  '15-1299': ['Computer and Mathematical Occupations',
#   'Computer Occupations',
#   'Miscellaneous Computer Occupations'],
#  '15-2000': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Not assigned'],
#  '15-2010': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Actuaries'],
#  '15-2011': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Actuaries'],
#  '15-2020': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Mathematicians'],
#  '15-2021': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Mathematicians'],
#  '15-2030': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Operations Research Analysts'],
#  '15-2031': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Operations Research Analysts'],
#  '15-2040': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Statisticians'],
#  '15-2041': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Statisticians'],
#  '15-2050': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Data Scientists'],
#  '15-2051': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Data Scientists'],
#  '15-2090': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Miscellaneous Mathematical Science Occupations'],
#  '15-2099': ['Computer and Mathematical Occupations',
#   'Mathematical Science Occupations',
#   'Miscellaneous Mathematical Science Occupations'],
#  '17-1000': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Not assigned'],
#  '17-1010': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Architects, Except Naval'],
#  '17-1011': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Architects, Except Naval'],
#  '17-1012': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Architects, Except Naval'],
#  '17-1020': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Surveyors, Cartographers, and Photogrammetrists'],
#  '17-1021': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Surveyors, Cartographers, and Photogrammetrists'],
#  '17-1022': ['Architecture and Engineering Occupations',
#   'Architects, Surveyors, and Cartographers',
#   'Surveyors, Cartographers, and Photogrammetrists'],
#  '17-2000': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Not assigned'],
#  '17-2010': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Aerospace Engineers'],
#  '17-2011': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Aerospace Engineers'],
#  '17-2020': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Agricultural Engineers'],
#  '17-2021': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Agricultural Engineers'],
#  '17-2030': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Bioengineers and Biomedical Engineers'],
#  '17-2031': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Bioengineers and Biomedical Engineers'],
#  '17-2040': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Chemical Engineers'],
#  '17-2041': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Chemical Engineers'],
#  '17-2050': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Civil Engineers'],
#  '17-2051': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Civil Engineers'],
#  '17-2060': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Computer Hardware Engineers'],
#  '17-2061': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Computer Hardware Engineers'],
#  '17-2070': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Electrical and Electronics Engineers'],
#  '17-2071': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Electrical and Electronics Engineers'],
#  '17-2072': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Electrical and Electronics Engineers'],
#  '17-2080': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Environmental Engineers'],
#  '17-2081': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Environmental Engineers'],
#  '17-2110': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Industrial Engineers, Including Health and Safety'],
#  '17-2111': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Industrial Engineers, Including Health and Safety'],
#  '17-2112': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Industrial Engineers, Including Health and Safety'],
#  '17-2120': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Marine Engineers and Naval Architects'],
#  '17-2121': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Marine Engineers and Naval Architects'],
#  '17-2130': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Materials Engineers'],
#  '17-2131': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Materials Engineers'],
#  '17-2140': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Mechanical Engineers'],
#  '17-2141': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Mechanical Engineers'],
#  '17-2150': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Mining and Geological Engineers, Including Mining Safety Engineers'],
#  '17-2151': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Mining and Geological Engineers, Including Mining Safety Engineers'],
#  '17-2160': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Nuclear Engineers'],
#  '17-2161': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Nuclear Engineers'],
#  '17-2170': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Petroleum Engineers'],
#  '17-2171': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Petroleum Engineers'],
#  '17-2190': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Miscellaneous Engineers'],
#  '17-2199': ['Architecture and Engineering Occupations',
#   'Engineers',
#   'Miscellaneous Engineers'],
#  '17-3000': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Not assigned'],
#  '17-3010': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Drafters'],
#  '17-3011': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Drafters'],
#  '17-3012': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Drafters'],
#  '17-3013': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Drafters'],
#  '17-3019': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Drafters'],
#  '17-3020': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3021': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3022': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3023': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3024': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3025': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3026': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3027': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3028': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3029': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Engineering Technologists and Technicians, Except Drafters'],
#  '17-3030': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Surveying and Mapping Technicians'],
#  '17-3031': ['Architecture and Engineering Occupations',
#   'Drafters, Engineering Technicians, and Mapping Technicians',
#   'Surveying and Mapping Technicians'],
#  '19-1000': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Not assigned'],
#  '19-1010': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Agricultural and Food Scientists'],
#  '19-1011': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Agricultural and Food Scientists'],
#  '19-1012': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Agricultural and Food Scientists'],
#  '19-1013': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Agricultural and Food Scientists'],
#  '19-1020': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Biological Scientists'],
#  '19-1021': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Biological Scientists'],
#  '19-1022': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Biological Scientists'],
#  '19-1023': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Biological Scientists'],
#  '19-1029': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Biological Scientists'],
#  '19-1030': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Conservation Scientists and Foresters'],
#  '19-1031': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Conservation Scientists and Foresters'],
#  '19-1032': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Conservation Scientists and Foresters'],
#  '19-1040': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Medical Scientists'],
#  '19-1041': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Medical Scientists'],
#  '19-1042': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Medical Scientists'],
#  '19-1090': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Miscellaneous Life Scientists'],
#  '19-1099': ['Life, Physical, and Social Science Occupations',
#   'Life Scientists',
#   'Miscellaneous Life Scientists'],
#  '19-2000': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Not assigned'],
#  '19-2010': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Astronomers and Physicists'],
#  '19-2011': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Astronomers and Physicists'],
#  '19-2012': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Astronomers and Physicists'],
#  '19-2020': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Atmospheric and Space Scientists'],
#  '19-2021': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Atmospheric and Space Scientists'],
#  '19-2030': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Chemists and Materials Scientists'],
#  '19-2031': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Chemists and Materials Scientists'],
#  '19-2032': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Chemists and Materials Scientists'],
#  '19-2040': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Environmental Scientists and Geoscientists'],
#  '19-2041': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Environmental Scientists and Geoscientists'],
#  '19-2042': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Environmental Scientists and Geoscientists'],
#  '19-2043': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Environmental Scientists and Geoscientists'],
#  '19-2090': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Miscellaneous Physical Scientists'],
#  '19-2099': ['Life, Physical, and Social Science Occupations',
#   'Physical Scientists',
#   'Miscellaneous Physical Scientists'],
#  '19-3000': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Not assigned'],
#  '19-3010': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Economists'],
#  '19-3011': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Economists'],
#  '19-3020': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Survey Researchers'],
#  '19-3022': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Survey Researchers'],
#  '19-3030': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Psychologists'],
#  '19-3032': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Psychologists'],
#  '19-3033': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Psychologists'],
#  '19-3034': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Psychologists'],
#  '19-3039': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Psychologists'],
#  '19-3040': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Sociologists'],
#  '19-3041': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Sociologists'],
#  '19-3050': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Urban and Regional Planners'],
#  '19-3051': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Urban and Regional Planners'],
#  '19-3090': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-3091': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-3092': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-3093': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-3094': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-3099': ['Life, Physical, and Social Science Occupations',
#   'Social Scientists and Related Workers',
#   'Miscellaneous Social Scientists and Related Workers'],
#  '19-4000': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Not assigned'],
#  '19-4010': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Agricultural and Food Science Technicians'],
#  '19-4012': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Agricultural and Food Science Technicians'],
#  '19-4013': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Agricultural and Food Science Technicians'],
#  '19-4020': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Biological Technicians'],
#  '19-4021': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Biological Technicians'],
#  '19-4030': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Chemical Technicians'],
#  '19-4031': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Chemical Technicians'],
#  '19-4040': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Environmental Science and Geoscience Technicians'],
#  '19-4042': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Environmental Science and Geoscience Technicians'],
#  '19-4043': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Environmental Science and Geoscience Technicians'],
#  '19-4044': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Environmental Science and Geoscience Technicians'],
#  '19-4050': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Nuclear Technicians'],
#  '19-4051': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Nuclear Technicians'],
#  '19-4060': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Social Science Research Assistants'],
#  '19-4061': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Social Science Research Assistants'],
#  '19-4070': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Forest and Conservation Technicians'],
#  '19-4071': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Forest and Conservation Technicians'],
#  '19-4090': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Miscellaneous Life, Physical, and Social Science Technicians'],
#  '19-4092': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Miscellaneous Life, Physical, and Social Science Technicians'],
#  '19-4099': ['Life, Physical, and Social Science Occupations',
#   'Life, Physical, and Social Science Technicians',
#   'Miscellaneous Life, Physical, and Social Science Technicians'],
#  '19-5000': ['Life, Physical, and Social Science Occupations',
#   'Occupational Health and Safety Specialists and Technicians',
#   'Not assigned'],
#  '19-5010': ['Life, Physical, and Social Science Occupations',
#   'Occupational Health and Safety Specialists and Technicians',
#   'Occupational Health and Safety Specialists and Technicians'],
#  '19-5011': ['Life, Physical, and Social Science Occupations',
#   'Occupational Health and Safety Specialists and Technicians',
#   'Occupational Health and Safety Specialists and Technicians'],
#  '19-5012': ['Life, Physical, and Social Science Occupations',
#   'Occupational Health and Safety Specialists and Technicians',
#   'Occupational Health and Safety Specialists and Technicians'],
#  '21-1000': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Not assigned'],
#  '21-1010': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1011': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1012': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1013': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1014': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1015': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1019': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Counselors'],
#  '21-1020': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Social Workers'],
#  '21-1021': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Social Workers'],
#  '21-1022': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Social Workers'],
#  '21-1023': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Social Workers'],
#  '21-1029': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Social Workers'],
#  '21-1090': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-1091': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-1092': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-1093': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-1094': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-1099': ['Community and Social Service Occupations',
#   'Counselors, Social Workers, and Other Community and Social Service Specialists',
#   'Miscellaneous Community and Social Service Specialists'],
#  '21-2000': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Not assigned'],
#  '21-2010': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Clergy'],
#  '21-2011': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Clergy'],
#  '21-2020': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Directors, Religious Activities and Education'],
#  '21-2021': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Directors, Religious Activities and Education'],
#  '21-2090': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Miscellaneous Religious Workers'],
#  '21-2099': ['Community and Social Service Occupations',
#   'Religious Workers',
#   'Miscellaneous Religious Workers'],
#  '23-1000': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Not assigned'],
#  '23-1010': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Lawyers and Judicial Law Clerks'],
#  '23-1011': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Lawyers and Judicial Law Clerks'],
#  '23-1012': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Lawyers and Judicial Law Clerks'],
#  '23-1020': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Judges, Magistrates, and Other Judicial Workers'],
#  '23-1021': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Judges, Magistrates, and Other Judicial Workers'],
#  '23-1022': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Judges, Magistrates, and Other Judicial Workers'],
#  '23-1023': ['Legal Occupations',
#   'Lawyers, Judges, and Related Workers',
#   'Judges, Magistrates, and Other Judicial Workers'],
#  '23-2000': ['Legal Occupations', 'Legal Support Workers', 'Not assigned'],
#  '23-2010': ['Legal Occupations',
#   'Legal Support Workers',
#   'Paralegals and Legal Assistants'],
#  '23-2011': ['Legal Occupations',
#   'Legal Support Workers',
#   'Paralegals and Legal Assistants'],
#  '23-2090': ['Legal Occupations',
#   'Legal Support Workers',
#   'Miscellaneous Legal Support Workers'],
#  '23-2093': ['Legal Occupations',
#   'Legal Support Workers',
#   'Miscellaneous Legal Support Workers'],
#  '23-2099': ['Legal Occupations',
#   'Legal Support Workers',
#   'Miscellaneous Legal Support Workers'],
#  '25-1000': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Not assigned'],
#  '25-1010': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Business Teachers, Postsecondary'],
#  '25-1011': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Business Teachers, Postsecondary'],
#  '25-1020': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Math and Computer Science Teachers, Postsecondary'],
#  '25-1021': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Math and Computer Science Teachers, Postsecondary'],
#  '25-1022': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Math and Computer Science Teachers, Postsecondary'],
#  '25-1030': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Engineering and Architecture Teachers, Postsecondary'],
#  '25-1031': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Engineering and Architecture Teachers, Postsecondary'],
#  '25-1032': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Engineering and Architecture Teachers, Postsecondary'],
#  '25-1040': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Life Sciences Teachers, Postsecondary'],
#  '25-1041': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Life Sciences Teachers, Postsecondary'],
#  '25-1042': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Life Sciences Teachers, Postsecondary'],
#  '25-1043': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Life Sciences Teachers, Postsecondary'],
#  '25-1050': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Physical Sciences Teachers, Postsecondary'],
#  '25-1051': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Physical Sciences Teachers, Postsecondary'],
#  '25-1052': ['Educational Instruction and Library Occupations',
#   'Postsecondary Teachers',
#   'Physical Sciences Teachers, Postsecondary'],
# ...
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Not assigned'],
#  '43-5010': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Cargo and Freight Agents'],
#  '43-5011': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Cargo and Freight Agents'],
#  '43-5020': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Couriers and Messengers'],
#  '43-5021': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Couriers and Messengers'],
#  '43-5030': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Dispatchers'],
#  '43-5031': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Dispatchers'],
#  '43-5032': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Dispatchers'],
#  '43-5040': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Meter Readers, Utilities'],
#  '43-5041': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Meter Readers, Utilities'],
#  '43-5050': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Postal Service Workers'],
#  '43-5051': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Postal Service Workers'],
#  '43-5052': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Postal Service Workers'],
#  '43-5053': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Postal Service Workers'],
#  '43-5060': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Production, Planning, and Expediting Clerks'],
#  '43-5061': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Production, Planning, and Expediting Clerks'],
#  '43-5070': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Shipping, Receiving, and Inventory Clerks'],
#  '43-5071': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Shipping, Receiving, and Inventory Clerks'],
#  '43-5110': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Weighers, Measurers, Checkers, and Samplers, Recordkeeping'],
#  '43-5111': ['Office and Administrative Support Occupations',
#   'Material Recording, Scheduling, Dispatching, and Distributing Workers',
#   'Weighers, Measurers, Checkers, and Samplers, Recordkeeping'],
#  '43-6000': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Not assigned'],
#  '43-6010': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Secretaries and Administrative Assistants'],
#  '43-6011': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Secretaries and Administrative Assistants'],
#  '43-6012': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Secretaries and Administrative Assistants'],
#  '43-6013': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Secretaries and Administrative Assistants'],
#  '43-6014': ['Office and Administrative Support Occupations',
#   'Secretaries and Administrative Assistants',
#   'Secretaries and Administrative Assistants'],
#  '43-9000': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Not assigned'],
#  '43-9020': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Data Entry and Information Processing Workers'],
#  '43-9021': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Data Entry and Information Processing Workers'],
#  '43-9022': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Data Entry and Information Processing Workers'],
#  '43-9030': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Desktop Publishers'],
#  '43-9031': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Desktop Publishers'],
#  '43-9040': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Insurance Claims and Policy Processing Clerks'],
#  '43-9041': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Insurance Claims and Policy Processing Clerks'],
#  '43-9050': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Mail Clerks and Mail Machine Operators, Except Postal Service'],
#  '43-9051': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Mail Clerks and Mail Machine Operators, Except Postal Service'],
#  '43-9060': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Office Clerks, General'],
#  '43-9061': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Office Clerks, General'],
#  '43-9070': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Office Machine Operators, Except Computer'],
#  '43-9071': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Office Machine Operators, Except Computer'],
#  '43-9080': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Proofreaders and Copy Markers'],
#  '43-9081': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Proofreaders and Copy Markers'],
#  '43-9110': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Statistical Assistants'],
#  '43-9111': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Statistical Assistants'],
#  '43-9190': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Miscellaneous Office and Administrative Support Workers'],
#  '43-9199': ['Office and Administrative Support Occupations',
#   'Other Office and Administrative Support Workers',
#   'Miscellaneous Office and Administrative Support Workers'],
#  '45-1000': ['Farming, Fishing, and Forestry Occupations',
#   'Supervisors of Farming, Fishing, and Forestry Workers',
#   'Not assigned'],
#  '45-1010': ['Farming, Fishing, and Forestry Occupations',
#   'Supervisors of Farming, Fishing, and Forestry Workers',
#   'First-Line Supervisors of Farming, Fishing, and Forestry Workers'],
#  '45-1011': ['Farming, Fishing, and Forestry Occupations',
#   'Supervisors of Farming, Fishing, and Forestry Workers',
#   'First-Line Supervisors of Farming, Fishing, and Forestry Workers'],
#  '45-2000': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Not assigned'],
#  '45-2010': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Agricultural Inspectors'],
#  '45-2011': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Agricultural Inspectors'],
#  '45-2020': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Animal Breeders'],
#  '45-2021': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Animal Breeders'],
#  '45-2040': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Graders and Sorters, Agricultural Products'],
#  '45-2041': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Graders and Sorters, Agricultural Products'],
#  '45-2090': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Miscellaneous Agricultural Workers'],
#  '45-2091': ['Farming, Fishing, and Forestry Occupations',
#   'Agricultural Workers',
#   'Miscellaneous Agricultural Workers'],
#  '45-3000': ['Farming, Fishing, and Forestry Occupations',
#   'Fishing and Hunting Workers',
#   'Not assigned'],
#  '45-3030': ['Farming, Fishing, and Forestry Occupations',
#   'Fishing and Hunting Workers',
#   'Fishing and Hunting Workers'],
#  '45-3031': ['Farming, Fishing, and Forestry Occupations',
#   'Fishing and Hunting Workers',
#   'Fishing and Hunting Workers'],
#  '45-4000': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Not assigned'],
#  '45-4010': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Forest and Conservation Workers'],
#  '45-4011': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Forest and Conservation Workers'],
#  '45-4020': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Logging Workers'],
#  '45-4021': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Logging Workers'],
#  '45-4022': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Logging Workers'],
#  '45-4023': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Logging Workers'],
#  '45-4029': ['Farming, Fishing, and Forestry Occupations',
#   'Forest, Conservation, and Logging Workers',
#   'Logging Workers'],
#  '47-1000': ['Construction and Extraction Occupations',
#   'Supervisors of Construction and Extraction Workers',
#   'Not assigned'],
#  '47-1010': ['Construction and Extraction Occupations',
#   'Supervisors of Construction and Extraction Workers',
#   'First-Line Supervisors of Construction Trades and Extraction Workers'],
#  '47-1011': ['Construction and Extraction Occupations',
#   'Supervisors of Construction and Extraction Workers',
#   'First-Line Supervisors of Construction Trades and Extraction Workers'],
#  '47-2000': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Not assigned'],
#  '47-2010': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Boilermakers'],
#  '47-2011': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Boilermakers'],
#  '47-2020': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Brickmasons, Blockmasons, and Stonemasons'],
#  '47-2021': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Brickmasons, Blockmasons, and Stonemasons'],
#  '47-2022': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Brickmasons, Blockmasons, and Stonemasons'],
#  '47-2030': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpenters'],
#  '47-2031': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpenters'],
#  '47-2040': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpet, Floor, and Tile Installers and Finishers'],
#  '47-2041': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpet, Floor, and Tile Installers and Finishers'],
#  '47-2042': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpet, Floor, and Tile Installers and Finishers'],
#  '47-2043': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpet, Floor, and Tile Installers and Finishers'],
#  '47-2044': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Carpet, Floor, and Tile Installers and Finishers'],
#  '47-2050': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Cement Masons, Concrete Finishers, and Terrazzo Workers'],
#  '47-2051': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Cement Masons, Concrete Finishers, and Terrazzo Workers'],
#  '47-2053': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Cement Masons, Concrete Finishers, and Terrazzo Workers'],
#  '47-2060': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Laborers'],
#  '47-2061': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Laborers'],
#  '47-2070': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Equipment Operators'],
#  '47-2071': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Equipment Operators'],
#  '47-2072': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Equipment Operators'],
#  '47-2073': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Construction Equipment Operators'],
#  '47-2080': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Drywall Installers, Ceiling Tile Installers, and Tapers'],
#  '47-2081': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Drywall Installers, Ceiling Tile Installers, and Tapers'],
#  '47-2082': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Drywall Installers, Ceiling Tile Installers, and Tapers'],
#  '47-2110': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Electricians'],
#  '47-2111': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Electricians'],
#  '47-2120': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Glaziers'],
#  '47-2121': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Glaziers'],
#  '47-2130': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Insulation Workers'],
#  '47-2131': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Insulation Workers'],
#  '47-2132': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Insulation Workers'],
#  '47-2140': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Painters and Paperhangers'],
#  '47-2141': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Painters and Paperhangers'],
#  '47-2142': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Painters and Paperhangers'],
#  '47-2150': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Pipelayers, Plumbers, Pipefitters, and Steamfitters'],
#  '47-2151': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Pipelayers, Plumbers, Pipefitters, and Steamfitters'],
#  '47-2152': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Pipelayers, Plumbers, Pipefitters, and Steamfitters'],
#  '47-2160': ['Construction and Extraction Occupations',
#   'Construction Trades Workers',
#   'Plasterers and Stucco Masons'],
#  ...}

# %%
output["00-0000"] = ["Not assigned"] * 3 
output["99-9999"] = ["Insufficient info"] * 3
output["45-2092"] = ['Farming, Fishing, and Forestry Occupations','Agricultural Workers', 'Miscellaneous Agricultural Workers']
output["45-2093"] = ['Farming, Fishing, and Forestry Occupations','Agricultural Workers', 'Miscellaneous Agricultural Workers']
output["45-2099"] = ['Farming, Fishing, and Forestry Occupations','Agricultural Workers', 'Miscellaneous Agricultural Workers']
output["25-2010"] = ['Educational Instruction and Library Occupations','Preschool, Elementary, Middle, Secondary, and Special Education Teachers','Preschool and Kindergarten Teachers']

# %%
import pickle

with open(os.path.join("datasets", 'code_to_description.pkl'), 'wb') as file:
    pickle.dump(output, file)
